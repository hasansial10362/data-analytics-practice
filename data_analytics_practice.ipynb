# %%
print("Hello Data Analytics")

a = 10
b = 5

print(a + b)
# Out:
# Hello Data Analytics
# 15

# %%
print("Hello Data Analytics")

a = 50
b = 10

print(a - b)
# Out:
# Hello Data Analytics
# 40

# %%
import pandas
import numpy
import matplotlib
import seaborn

print("All libraries working")
# Out:
# All libraries working

# %%
import numpy as np

arr = np.array([1,2,3,4,5])
print(arr)
print("Sum:", np.sum(arr))
# Out:
# [1 2 3 4 5]
# Sum: 15

# %%
import numpy as np

arr = np.array([1,2,3,4,5])
print(arr)
print("Sum:", np.sum(arr))
# Out:
# [1 2 3 4 5]
# Sum: 15

# %%
import pandas as pd

data = {
    "Name": ["Ali", "Sara", "Ahmed"],
    "Age": [22, 21, 23]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0    Ali   22
# 1   Sara   21
# 2  Ahmed   23

# %%
import matplotlib.pyplot as plt

x = [1,2,3]
y = [10,20,30]

plt.plot(x,y)
plt.title("Simple Graph")
plt.show()

# %%
import seaborn as sns

sns.barplot(x=["Ali","Sara","Ahmed"], y=[85,90,80])
plt.show()
